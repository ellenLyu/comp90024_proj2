# %%
import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener 
from tweepy import OAuthHandler
from tweepy import TweepError
import json
import pandas as pd
import sys
import time



consumer_key = 'rZFruNsPGW0dztpugftVGj837'  
consumer_secret = 'L6AzbTcwZZuJYWkBxt5mL7Ern7sKUxHuGyUqKE7WSql9vkRZNG'  
access_token = '1381264077268283393-otuXk0e8EVuw5BnrYbKpEuVDButxQI'  
access_token_secret = '9HMXSW6FzC24nlA1sccTaF8Wwypdh2KHbpxz2GT6jSB94'  


# consumer_key = 'T08RKyC74lJTtOeozaBMSjbs9'  
# consumer_secret = 'nBbdYRK7BmsoD5h23l9OT4ICQ2CABnmcCJAJunZtFtv556bYzL'  
# access_token = '1388437713536229380-rUyKUTYcwz887Hw0AdsLbhZtfapxeJ'  
# access_token_secret = 'bmZSM7APPq9MFbNZqiBsMkE9nk3rpZVU07qDzNfePg6T2'  


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  
auth.set_access_token(access_token, access_token_secret)  
api = tweepy.API(auth, wait_on_rate_limit=False)

# %%
geo = '-37.972566514250005,145.1525293990965,50km'
tweet_count = 10
keyword = 'covid OR outbreak -filter:retweets'

auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=False)
for tweet in tweepy.Cursor(api.search, q=keyword, include_rts=False, geocode=geo).items(10):
    print(tweet.text)
# Out:
# @rodhadpsg Ha. Yes, covid-enforced. Hopefully not for much longer.
# @crk5 Covid cleaning I guess 🤪
# The first repatriation flight from India landed in Darwin today, marking the end of the government's travel ban fro… https://t.co/SrdNgvHl6i
# @WhereIsJGaltNow @kylenabecker Let me see. Where I am (500K) we have not seen Covid since mid-last year. Hard and f… https://t.co/EtEFQo8E6R
# My latest one for @SBS
# “Family comes first” while expecting their first child; this Indian - Australian couple took… https://t.co/aPvCN19hcn
# @nathanmj22 This will be trending by nights end the way he’s going... dare I say an outbreak of usage!
# @BJP4India @narendramodi Free vaccines..
# Ha h ....
# Thats their role is anyway
# They are for the ppl &amp; it's ppl mone… https://t.co/rOoTO40d0m
# First repatriation flight from India arrives in Darwin following end of COVID-19 travel ban.
#
# It was scheduled to c… https://t.co/MGNZVaoKck
# Bizarre - elimination was called 'unrealistic and dangerous'.
#
# Yet that's what we achieved, underpinning a stunnin… https://t.co/JoJEBmo5mT
# @billbowtell @leighsales @smh Nice straw man you've built
#
# No serious commentator is suggesting opening up now.
#
# B… https://t.co/7GiAse2Ttj

# %%
geo = "-37.788531,144.947731,10km"
# keyword = 'covid OR outbreak -filter:retweets'
keyword = "plane fly OR car drive OR covid OR outbreak -filter:retweets"

auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=False)
i = 0
for tweet in tweepy.Cursor(api.search, q=keyword, include_rts=False, geocode=geo).items(5):
    print("i =", i, tweet.text, '\n')
    tweet._json['suburb'] = "test"
    print(tweet._json)
    i += 1
# Out:
# i = 0 I’m not a logistics expert, but if I were organising repat flights from India to Australia, I’d anticipate some peo… https://t.co/lug6y73zEy
#
# {'created_at': 'Sat May 15 00:39:34 +0000 2021', 'id': 1393365402718130177, 'id_str': '1393365402718130177', 'text': 'I’m not a logistics expert, but if I were organising repat flights from India to Australia, I’d anticipate some peo… https://t.co/lug6y73zEy', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/lug6y73zEy', 'expanded_url': 'https://twitter.com/i/web/status/1393365402718130177', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 34131253, 'id_str': '34131253', 'name': 'Ross Floate', 'screen_name': 'RossFloate', 'location': 'Melbourne, Australia', 'description': 'You can eat a hot dog you found on the ground as long as you say it’s a rescue.', 'url': 'https://t.co/IfMovwzE2G', 'entities': {'url': {'urls': [{'url': 'https://t.co/IfMovwzE2G', 'expanded_url': 'http://rossfloate.com', 'display_url': 'rossfloate.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2086, 'friends_count': 2280, 'listed_count': 51, 'created_at': 'Wed Apr 22 01:36:26 +0000 2009', 'favourites_count': 14469, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 27320, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1063021770846818304/DOiWLJtf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1063021770846818304/DOiWLJtf_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34131253/1542278071', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 5, 'favorited': False, 'retweeted': False, 'lang': 'en', 'suburb': 'test'}
# i = 1 @elonmusk So to all the negative comments, if you drive a car, if you fly in a plane, heck if you live in the 21st… https://t.co/XiWHROgf0C
#
# {'created_at': 'Fri May 14 09:40:51 +0000 2021', 'id': 1393139235452977154, 'id_str': '1393139235452977154', 'text': '@elonmusk So to all the negative comments, if you drive a car, if you fly in a plane, heck if you live in the 21st… https://t.co/XiWHROgf0C', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'elonmusk', 'name': 'Elon Musk', 'id': 44196397, 'id_str': '44196397', 'indices': [0, 9]}], 'urls': [{'url': 'https://t.co/XiWHROgf0C', 'expanded_url': 'https://twitter.com/i/web/status/1393139235452977154', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1392947696470659072, 'in_reply_to_status_id_str': '1392947696470659072', 'in_reply_to_user_id': 44196397, 'in_reply_to_user_id_str': '44196397', 'in_reply_to_screen_name': 'elonmusk', 'user': {'id': 2855535410, 'id_str': '2855535410', 'name': 'Wil Ho', 'screen_name': 'WilHo_AI', 'location': 'Melbourne, Australia', 'description': 'Runs a team of developers focused on JS, Python and Serverless. Interested in Artificial Intelligence, Open Banking, Biohacking for longevity and Skateboarding.', 'url': 'https://t.co/YMfIUfKZre', 'entities': {'url': {'urls': [{'url': 'https://t.co/YMfIUfKZre', 'expanded_url': 'https://www.linkedin.com/in/wil-ho-9965ba3/', 'display_url': 'linkedin.com/in/wil-ho-9965…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 15, 'friends_count': 144, 'listed_count': 0, 'created_at': 'Tue Oct 14 12:51:36 +0000 2014', 'favourites_count': 52, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 90, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1171765995435806720/caoBf9fi_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1171765995435806720/caoBf9fi_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2855535410/1569019517', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en', 'suburb': 'test'}
# i = 2 In the latest of several novelty flights the airline has launched in the wake of the COVID-19 pandemic, a Qantas pl… https://t.co/OCFUNWmeY1
#
# {'created_at': 'Tue May 11 01:47:31 +0000 2021', 'id': 1391932951374536714, 'id_str': '1391932951374536714', 'text': 'In the latest of several novelty flights the airline has launched in the wake of the COVID-19 pandemic, a Qantas pl… https://t.co/OCFUNWmeY1', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/OCFUNWmeY1', 'expanded_url': 'https://twitter.com/i/web/status/1391932951374536714', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://www.echobox.com" rel="nofollow">Echobox</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 32201814, 'id_str': '32201814', 'name': 'The Age', 'screen_name': 'theage', 'location': 'Melbourne, Australia', 'description': 'Breaking news. Must-read columnists. Award-winning investigative journalism. Independent. Always. 🗞️', 'url': 'http://t.co/aFGMIHFZKT', 'entities': {'url': {'urls': [{'url': 'http://t.co/aFGMIHFZKT', 'expanded_url': 'http://www.theage.com.au', 'display_url': 'theage.com.au', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 906326, 'friends_count': 1200, 'listed_count': 4648, 'created_at': 'Thu Apr 16 23:28:23 +0000 2009', 'favourites_count': 484, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 125314, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1091122118547230722/ZWXcd6en_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1091122118547230722/ZWXcd6en_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32201814/1584930729', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'BDDCAD', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 6, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en', 'suburb': 'test'}

# %%
tweet_count = 1000
keyword = "plane fly OR car drive OR covid OR outbreak -filter:retweets"


def tweet_collector(geo, keyword, tweet_count):

    while tweet_count > 0:
        try:
            for page in tweepy.Cursor(api.search, q=keyword, include_rts=False, geocode=geo).pages():
                print("new page \n")
                for tweet in page:
                    #print(str(tweet._json))
                    print(tweet.text, "id:", tweet.id_str)
                    if tweet_count == 0:
                        print("Collection finished")
                        return None
                    tweet_count -= 1
        except TweepError as e:
            print(e)
            print(e.response)
            print(e.response.status_code)
    print("Collection finished")


tweet_collector(geo, keyword, tweet_count)
# Out:
# Twitter error response: status code = 429
# <Response [429]>
# 429
# Twitter error response: status code = 429
# <Response [429]>
# 429
# Twitter error response: status code = 429
# <Response [429]>
# 429
# Twitter error response: status code = 429
# <Response [429]>
# 429
# Twitter error response: status code = 429
# <Response [429]>
# 429
# Twitter error response: status code = 429
# <Response [429]>
# 429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-919e0ee91cf9> in <module>
#      23
#      24
# ---> 25 tweet_collector(geo, keyword, tweet_count)
#
# <ipython-input-78-919e0ee91cf9> in tweet_collector(geo, keyword, tweet_count)
#       7     while tweet_count > 0:
#       8         try:
# ----> 9             for page in tweepy.Cursor(api.search, q=keyword, include_rts=False, geocode=geo).pages():
#      10                 print("new page \n")
#      11                 for tweet in page:
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# KeyboardInterrupt:

# %%
import json


with open("melb_coordinates.json", "r") as f:
    melb_coordinates = json.load(f)

# %%
melb_coordinates
# Out:
# {'cremorne': [-37.829719, 144.990346],
#  'caulfield': [-37.880479, 145.026806],
#  'carnegie': [-37.889336, 145.058121],
#  'kingsville': [-37.812635, 144.881803],
#  'south kingsville': [-37.833627, 144.87074199999998],
#  'tottenham': [-37.799065, 144.857829],
#  'balaclava': [-37.869023, 144.995478],
#  'fitzroy north': [-37.7834, 144.98468799999998],
#  'kingsbury': [-37.714064, 145.035103],
#  'gardenvale': [-37.896915, 145.005249],
#  'windsor': [-37.856159000000005, 144.9922],
#  'caulfield south': [-37.886903000000004, 145.02197900000002],
#  'maidstone': [-37.782096, 144.874299],
#  'hawthorn': [-37.88986, 145.02141699999999],
#  'prahran': [-37.849577000000004, 144.99371399999998],
#  'essendon north': [-37.744374, 144.909853],
#  'seddon': [-37.808769, 144.895486],
#  'airport west': [-37.711698, 144.88703700000002],
#  'black rock': [-37.973503, 145.01658],
#  'williamstown north': [-37.857681, 144.88704099999998],
#  'northcote': [-37.769857, 144.995276],
#  'fairfield': [-37.776946, 145.018479],
#  'thornbury': [-37.75504, 144.99858899999998],
#  'princes hill': [-37.780995000000004, 144.96279199999998],
#  'clifton hill': [-37.788118, 144.992067],
#  'abbotsford': [-37.801781, 144.998752],
#  'brunswick east': [-37.76491, 144.979567],
#  'collingwood': [-37.800366, 144.984149],
#  'fitzroy': [-37.859514000000004, 144.977808],
#  'brunswick': [-37.794105, 144.979191],
#  'carlton north': [-37.784337, 144.96974699999998],
#  'carlton': [-37.960325, 145.215601],
#  'parkville': [-37.788531, 144.947731],
#  'armadale': [-37.85934, 145.018505],
#  'balwyn north': [-37.792835, 145.071727],
#  'toorak': [-37.84216, 145.017966],
#  'kooyong': [-37.840702, 145.032101],
#  'burnley': [-37.826869, 145.00709799999998],
#  'kew east': [-37.796246000000004, 145.049017],
#  'kew': [-37.797982, 145.053727],
#  'canterbury': [-37.824249, 145.073114],
#  'camberwell': [-37.836011, 145.062173],
#  'hawthorn east': [-37.782253999999995, 145.001811],
#  'southbank': [-37.823258, 144.965926],
#  'ormond': [-37.904059000000004, 145.040899],
#  'balwyn': [-37.809701000000004, 145.082303],
#  'preston': [-37.738735999999996, 145.00051499999998],
#  'elwood': [-37.888121000000005, 144.985026],
#  'docklands': [-37.814719000000004, 144.948039],
#  'richmond': [-37.818587, 144.999181],
#  'east melbourne': [-38.105449, 145.147855],
#  'south yarra': [-37.837883000000005, 144.991123],
#  'middle park': [-37.849721, 144.965136],
#  'glen iris': [-37.854687, 145.067215],
#  'north melbourne': [-37.905996, 145.056254],
#  'hadfield': [-37.707238000000004, 144.93832],
#  'caulfield north': [-37.901678000000004, 145.02357],
#  'brunswick west': [-37.762489, 144.961176],
#  'coburg north': [-37.730841999999996, 144.971699],
#  'malvern east': [-37.878370000000004, 145.067892],
#  'reservoir': [-37.716896999999996, 145.00698500000001],
#  'malvern': [-37.861427, 145.02850800000002],
#  'glen huntly': [-37.889239, 145.040629],
#  'coburg': [-37.743188, 144.96627900000001],
#  'fawkner': [-37.759823, 144.89571],
#  'ashburton': [-37.863393, 145.07942],
#  'pascoe vale south': [-37.739197999999995, 144.945722],
#  'caulfield east': [-37.875412, 145.041976],
#  'travancore': [-37.777772999999996, 144.929915],
#  'pascoe vale': [-37.727568, 144.939122],
#  'st kilda east': [-37.866458, 145.000047],
#  'south melbourne': [-37.93291, 145.033718],
#  'essendon': [-37.754973, 144.917407],
#  'flemington': [-37.788375, 144.93147199999999],
#  'albert park': [-37.840705, 144.95571],
#  'murrumbeena': [-37.89069, 145.067589],
#  'st kilda': [-37.867573, 144.978814],
#  'glenroy': [-37.704581, 144.915758],
#  'kensington': [-37.794333, 144.929217],
#  'ripponlea': [-37.876692, 144.996194],
#  'hughesdale': [-37.895763, 145.07654499999998],
#  'st kilda west': [-37.860901, 144.972523],
#  'strathmore': [-37.735876, 144.919176],
#  'moonee ponds': [-37.765707, 144.919163],
#  'aberfeldie': [-37.75669, 144.89625900000001],
#  'oak park': [-37.71817, 144.919959],
#  'ascot vale': [-37.77583, 144.923377],
#  'elsternwick': [-37.884724, 145.004153],
#  'west melbourne': [-37.806255, 144.941123],
#  'mckinnon': [-37.910967, 145.037483],
#  'gowanbrae': [-37.706315999999994, 144.89488500000002],
#  'strathmore heights': [-37.716678, 144.897568],
#  'bentleigh': [-37.918057, 145.03544399999998],
#  'brighton east': [-37.904879, 145.002603],
#  'footscray': [-37.79977, 144.89958700000003],
#  'port melbourne': [-37.846333, 144.88574599999998],
#  'maribyrnong': [-37.772228999999996, 144.886116],
#  'bentleigh east': [-37.927402, 145.059412],
#  'brighton': [-37.913149, 144.991682],
#  'essendon west': [-37.753802, 144.888271],
#  'seaholme': [-37.867992, 144.84360900000001],
#  'niddrie': [-37.736031, 144.889072],
#  'hampton east': [-37.933603000000005, 145.034175],
#  'yarraville': [-37.816178, 144.889774],
#  'spotswood': [-37.82967, 144.885078],
#  'newport': [-37.842477, 144.88314499999998],
#  'avondale heights': [-37.742284000000005, 144.81515],
#  'west footscray': [-37.797701, 144.879924],
#  'braybrook': [-37.779309000000005, 144.85535900000002],
#  'beaumaris': [-37.986284999999995, 145.032876],
#  'williamstown': [-37.856902000000005, 144.897698],
#  'sandringham': [-37.952493, 145.012316],
#  'altona north': [-37.842878999999996, 144.850049],
#  'altona': [-37.869275, 144.830286],
#  'altona meadows': [-37.871632, 144.778084],
#  'seabrook': [-37.877626, 144.75777]}

# %%
for suburb, coordinates in melb_coordinates.items():
    lat, lon = coordinates
    geocode = f'{lat},{lon},10km'
    try:
        for tweet in tweepy.Cursor(api.search, q=keyword, include_rts=False, geocode=geocode).items(500):
            tweet._json['suburb'] = suburb
    except TweepError as e:
        print(e)
        if e.response.status_code == 429:
            print("Waiting on limit for 15 mins")
            time.sleep(15 * 60 + 1)
        else:
            time.sleep(10)
        continue
